# %%
import random 

user_name = input("Enter Your Name : ")
user = input("Choose Odd/Even: ").lower()
while True:
    choose = input("Enter the numbers from 1 to 6: ")
    if choose in "123456" and choose != '':
        choose = int(choose)
    else:
        print("\033[1mInvalid Input!!\033[0m\nPlease enter numbers from 1-6 only\n")
        continue
    comp = random.randint(1, 6)
    print(f"You entered : {choose}\nComputer has chosen : {comp}")
    add = choose + comp
    choice = ["Batting", "Bowling"]
    comp_choice = random.choice(choice)
    break

def batting():
    global gameover 
    gameover = False 
    print("Be ready for Batting!!")
    print("_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_> \033[1mLet's begin!!\033[0m <-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-\n")
    user_score = 0
    comp_runs = 0
    while True:
        user = input("Enter the number in between 1-6 for batting ")
        if user in "123456" and user != '':
            user = int(user)
        else:
            print("\033[1mInvalid Input!!\033[0m\nPlease enter a valid input!!\n")
            continue 
        computer = random.randint(1,6)
        print(f"You entered :{user}\nComputer chosen :{computer}")
        user_score += user
        print("Your current runs : ",user_score)
        print('-------------------------------------------------------------------------------------------')
        if user == computer:
            print("Oops,Computer has taken your wicket!!\nYou are done with batting")
            print(f"Computer is ready for batting\nComputer needs {user_score + 1} to win!")
            print('-------------------------------------------------------------------------------------------')
            print('-------------------------------------------------------------------------------------------')
            break
    while True:
        user = input("Enter the number in between 1-6 for bowling\n")
        if user in "123456789" and user != '':
            user = int(user)
        else:
            print("\033[1mInvalid Input!!\033[0m\nPlease enter a valid input!!\n")
            continue 
        computer = random.randint(1,6)
        print(f"You entered {user}\nComputer chosen {computer}")
        comp_runs +=computer
        print("Computer current runs : ",comp_runs)
        print('-------------------------------------------------------------------------------------------')
        if comp_runs > user_score :
            print(f"Ooooh!!,Computer taken the match\n\033[1mComputer won by {comp_runs - user_score} runs!!\033[0m")
            print("Better luck next time!!")
            print('-------------------------------------------------------------------------------------------')
            print('--------------------------------------* \033[1mMatch Ended\033[0m *--------------------------------------')
            print('-------------------------------------------------------------------------------------------')
            gameover = True
            break
        elif user == computer:
            print(f"Great!!\nYou got computer wicket!!\n{user_name} taken the match!!")
            print(f"{user_name} won the match by {user_score - comp_runs} runs")
            print('-------------------------------------------------------------------------------------------')
            print('--------------------------------------* \033[1mMatch Ended\033[0m *--------------------------------------')
            print('-------------------------------------------------------------------------------------------')
            gameover = True
            break

def bowling():
    global gameover
    gameover = False
    print("Prepare for the bowling!!")
    print("_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_> \033[1mLet's begin!!\033[0m <-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-\n")
    user_score = 0
    comp_runs = 0
    while True:
        user = input("Enter the number in between 1-6 for bowling ")
        if user in "123456789" and user != '':
            user = int(user)
        else:
            print("\033[1mInvalid Input!!\033[0m\nPlease enter numbers from 1-6 only\n")
            continue 
        user = int(user)
        computer = random.randint(1,6)
        print(f"You entered {user}\nComputer chosen {computer}")
        comp_runs += computer
        print("Computer current runs : ",comp_runs)
        print('-------------------------------------------------------------------------------------------')
        if user == computer:
            print("Great!!,You got computer wicket\nComputer are done with batting")
            print(f"Are you ready for batting\nYou needs {comp_runs + 1} to win!")
            print('-------------------------------------------------------------------------------------------')
            print('-------------------------------------------------------------------------------------------')
            break
    while True:
        user = input("Enter the number in between 1-6 for batting")
        if user in "123456789" and user != '':
            user = int(user)
        else:
            print("\033[1mInvalid Input!!\033[0m\nPlease enter a valid input!!\n")
            continue 
        computer = random.randint(1,6)
        print(f"You entered {user}\nComputer chosen {computer}")
        user_score += user
        print("Your current runs : ",user_score)
        print('-------------------------------------------------------------------------------------------')
        if user_score > comp_runs :
            print(f"Great!!\n{user_name} won the match by {user_score - comp_runs} runs")
            print('-------------------------------------------------------------------------------------------')
            print('--------------------------------------* \033[1mMatch Ended\033[0m *--------------------------------------')
            print('-------------------------------------------------------------------------------------------')
            gameover = True
            break
        elif user == computer:
            print("Oops,Computer has taken your wicket!!")
            print(f"\033[1mComputer won the match by {comp_runs - user_score} runs!!\033[0m")    
            print("Better luck next time!!")
            print('-------------------------------------------------------------------------------------------')
            print('--------------------------------------* \033[1mMatch Ended\033[0m *--------------------------------------')
            print('-------------------------------------------------------------------------------------------')
            gameover = True 
            break
        
if add % 2 == 0:
    if user == "even" or user == "e":
        BatorBall = input("\033[1mYou won the toss!!!\033[0m\nYou have the choice to choose Batting/Bowling\n1 for Batting\n2 for Bowling\n ")   
        if BatorBall == "1":
            batting()
        elif BatorBall == "2":
            bowling()
        else:
            print("\033[1mInvalid Input!!\033[0m\nPlease enter a valid input!!")
    else:
        print(f"Computer has won the toss\nComputer chosen {comp_choice}")
        if comp_choice == "Batting":
            bowling()
        else:
            batting()
elif add % 2 != 0:
    if user == "odd" or user == "o":
        BatorBall = input("\033[1mYou won the toss!!!\033[0m\nYou have the choice to choose Batting/Bowling\n1 for Batting\n2 for Bowling\n ")
        if BatorBall == "1":
            batting()
        elif BatorBall == "2":
             bowling()
        else:
            print("\033[1mInvalid Input!!\033[0m\nPlease enter a valid input!!")
    else:
        print(f"Computer has won the toss\nComputer choosed {comp_choice}")
        if comp_choice == "Batting":
            bowling()
        else: 
            batting()
# Out:
# Enter Your Name : n
# Choose Odd/Even: e
# Enter the numbers from 1 to 6: 2
# You entered : 2
# Computer has chosen : 1
# Computer has won the toss
# Computer choosed Bowling
# Be ready for Batting!!
# _-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_> Let's begin!! <-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-
#
# Enter the number in between 1-6 for batting 1
# You entered :1
# Computer chosen :4
# Your current runs :  1
# -------------------------------------------------------------------------------------------
# Enter the number in between 1-6 for batting 2
# You entered :2
# Computer chosen :4
# Your current runs :  3
# -------------------------------------------------------------------------------------------
# Enter the number in between 1-6 for batting 3
# You entered :3
# Computer chosen :3
# Your current runs :  6
# -------------------------------------------------------------------------------------------
# Oops,Computer has taken your wicket!!
# You are done with batting
# ...
